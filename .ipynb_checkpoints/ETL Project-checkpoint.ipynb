# %%
# importing dependencies
import pandas as pd
from sqlalchemy import create_engine
import numpy as np

# %% [markdown]
# # Bringing in data from CSVs

# %%
# importing first csv file
top50_file = "Resources/spotify_top_50.csv"
top50_df = pd.read_csv(top50_file)
top50_df.head()
# Out:
#                                Song       Artists  Weeks at no 1  \
# 0                               WAP       Cardi B            1.0
# 1  Savage Love (Laxed – Siren Beat)     Jawsh 685            2.0
# 2                          Cardigan  Taylor Swift            1.0
# 3                          Rockstar        DaBaby            7.0
# 4                        Rain on Me     Lady Gaga            1.0
#
#    Average_Streams (Millions) Date_Published Date_Achieved
# 0                        40.3       7-Aug-20     20-Aug-20
# 1                        32.2      11-Jun-20      6-Aug-20
# 2                        35.7      24-Jul-20     30-Jul-20
# 3                        37.4      24-Apr-20      4-Jun-20
# 4                        41.6      22-May-20     28-May-20

# %%
# # importing second csv file
# decade_file = "Resources/spotify_top_songs_by_decade.csv"
# decade_df = pd.read_csv(decade_file, encoding='utf-8')
# decade_df.head()

# %%
# importing third csv file
century_file = "Resources/century_data.csv"
century_df = pd.read_csv(century_file)
century_df.head()
# Out:
#    acousticness                    artists  danceability  duration_ms  energy  \
# 0      0.991000            ['Mamie Smith']         0.598       168333   0.224
# 1      0.643000  ["Screamin' Jay Hawkins"]         0.852       150200   0.517
# 2      0.993000            ['Mamie Smith']         0.647       163827   0.186
# 3      0.000173        ['Oscar Velazquez']         0.730       422087   0.798
# 4      0.295000                   ['Mixe']         0.704       165224   0.707
#
#    explicit                      id  instrumentalness  key  liveness  \
# 0         0  0cS0A1fUEUd1EW3FcF8AEI          0.000522    5    0.3790
# 1         0  0hbkKFIJm7Z05H8Zl9w30f          0.026400    5    0.0809
# 2         0  11m7laMUgmOKqI3oYzuhne          0.000018    0    0.5190
# 3         0  19Lc5SfJJ5O1oaxY0fpwfh          0.801000    2    0.1280
# 4         1  2hJjbsLCytGsnAHfdsLejp          0.000246   10    0.4020
#
#    loudness  mode                                               name  \
# 0   -12.628     0                           Keep A Song In Your Soul
# 1    -7.261     0                               I Put A Spell On You
# 2   -12.098     1                                       Golfing Papa
# 3    -7.311     1  True House Music - Xavier Santos & Carlos Gomi...
# 4    -6.036     0                                          Xuniverxe
#
#    popularity release_date  speechiness    tempo  valence  year
# 0          12         1920       0.0936  149.976   0.6340  1920
# 1           7     1/5/1920       0.0534   86.889   0.9500  1920
# 2           4         1920       0.1740   97.600   0.6890  1920
# 3          17     1/1/1920       0.0425  127.997   0.0422  1920
# 4           2    10/1/1920       0.0768  122.076   0.2990  1920

# %% [markdown]
# # Transform top50_df

# %%
top50_df.columns
# Out:
# Index(['Song', 'Artists', 'Weeks at no 1', 'Average_Streams (Millions)',
#        'Date_Published', 'Date_Achieved'],
#       dtype='object')

# %%
# choosing columns we want
top50_transformed = top50_df[["Song", "Artists", "Average_Streams (Millions)", "Date_Achieved"]].copy()
# top50_transformed.head()

# columns are already named as we would want

# cleaning data by dropping duplicates/nulls and setting the index
top50_transformed.drop_duplicates("Song", inplace=True)
top50_transformed.set_index("Song", inplace=True)

# creating new instance of df and replacing nan values with empty strings
top50_trans = top50_transformed.replace(np.nan, '', regex=True)

top50_trans.head(10)
# Out:
#                                        Artists  Average_Streams (Millions)  \
# Song
# WAP                                    Cardi B                        40.3
# Savage Love (Laxed – Siren Beat)     Jawsh 685                        32.2
# Cardigan                          Taylor Swift                        35.7
# Rockstar                                DaBaby                        37.4
# Rain on Me                           Lady Gaga                        41.6
# The Scotts                        Travis Scott                        48.4
# Blinding Lights                     The Weeknd                        42.0
# The Box                            Roddy Ricch                        46.2
# Lose You to Love Me               Selena Gomez                        47.2
# Dance Monkey                       Tones and I                        46.2
#
#                                  Date_Achieved
# Song
# WAP                                  20-Aug-20
# Savage Love (Laxed – Siren Beat)      6-Aug-20
# Cardigan                             30-Jul-20
# Rockstar                              4-Jun-20
# Rain on Me                           28-May-20
# The Scotts                           30-Apr-20
# Blinding Lights                      27-Feb-20
# The Box                              13-Feb-20
# Lose You to Love Me                  31-Oct-19
# Dance Monkey                         17-Oct-19

# %% [markdown]
# # Transform decade_df

# %%
decade_df.head()
# Out:
#    Unnamed: 0                 title      artist        top genre  year  bpm  \
# 0           1      Hey, Soul Sister       Train       neo mellow  2010   97
# 1           2  Love The Way You Lie      Eminem  detroit hip hop  2010   87
# 2           3               TiK ToK       Kesha        dance pop  2010  120
# 3           4           Bad Romance   Lady Gaga        dance pop  2010  119
# 4           5  Just the Way You Are  Bruno Mars              pop  2010  109
#
#    nrgy  dnce  dB  live  val  dur  acous  spch  pop
# 0    89    67  -4     8   80  217     19     4   83
# 1    93    75  -5    52   64  263     24    23   82
# 2    84    76  -3    29   71  200     10    14   80
# 3    92    70  -4     8   71  295      0     4   79
# 4    84    64  -5     9   43  221      2     4   78

# %%
decade_df.columns
# Out:
# Index(['Unnamed: 0', 'title', 'artist', 'top genre', 'year', 'bpm', 'nrgy',
#        'dnce', 'dB', 'live', 'val', 'dur', 'acous', 'spch', 'pop'],
#       dtype='object')

# %%
# choosing columns we want
decade_transformed = decade_df[["title", "artist", "top genre", "year","bpm","nrgy",\
                                "dnce","dB","live","val","dur","acous","spch","pop"]].copy()

# decade_transformed.head()

#renaming columns
decade_transformed = decade_transformed.rename(columns={"title": "Song", "artist": "Artist_dec", "top genre": "Genre",\
                            "year":"Year", "bpm":"Beats per minute", "nrgy": "Energy", "dnce":"Danceability",\
                            "dB":"Loudness","live":"Liveness","val":"Valence","dur":"Duration","acous":"Acousticness",\
                            "spch":"Speechiness","pop":"Popularity"})
# decade_transformed

# cleaning data by dropping duplicates/nulls and setting the index
decade_transformed.drop_duplicates("Song", inplace=True)
decade_transformed.set_index("Song", inplace=True)
decade_transformed['Genre'] = decade_transformed['Genre'].str.title()

# creating new instance of df and replacing nan values with empty strings
decade_trans = decade_transformed.replace(np.nan, '', regex=True)

decade_trans.head()
# Out:
#                       Artist_dec            Genre  Year  Beats per minute  \
# Song
# Hey, Soul Sister           Train       Neo Mellow  2010                97
# Love The Way You Lie      Eminem  Detroit Hip Hop  2010                87
# TiK ToK                    Kesha        Dance Pop  2010               120
# Bad Romance            Lady Gaga        Dance Pop  2010               119
# Just the Way You Are  Bruno Mars              Pop  2010               109
#
#                       Energy  Danceability  Loudness  Liveness  Valence  \
# Song
# Hey, Soul Sister          89            67        -4         8       80
# Love The Way You Lie      93            75        -5        52       64
# TiK ToK                   84            76        -3        29       71
# Bad Romance               92            70        -4         8       71
# Just the Way You Are      84            64        -5         9       43
#
#                       Duration  Acousticness  Speechiness  Popularity
# Song
# Hey, Soul Sister           217            19            4          83
# Love The Way You Lie       263            24           23          82
# TiK ToK                    200            10           14          80
# Bad Romance                295             0            4          79
# Just the Way You Are       221             2            4          78

# %% [markdown]
# # Transform century_df

# %%
century_df.head()
# Out:
#    acousticness                    artists  danceability  duration_ms  energy  \
# 0      0.991000            ['Mamie Smith']         0.598       168333   0.224
# 1      0.643000  ["Screamin' Jay Hawkins"]         0.852       150200   0.517
# 2      0.993000            ['Mamie Smith']         0.647       163827   0.186
# 3      0.000173        ['Oscar Velazquez']         0.730       422087   0.798
# 4      0.295000                   ['Mixe']         0.704       165224   0.707
#
#    explicit                      id  instrumentalness  key  liveness  \
# 0         0  0cS0A1fUEUd1EW3FcF8AEI          0.000522    5    0.3790
# 1         0  0hbkKFIJm7Z05H8Zl9w30f          0.026400    5    0.0809
# 2         0  11m7laMUgmOKqI3oYzuhne          0.000018    0    0.5190
# 3         0  19Lc5SfJJ5O1oaxY0fpwfh          0.801000    2    0.1280
# 4         1  2hJjbsLCytGsnAHfdsLejp          0.000246   10    0.4020
#
#    loudness  mode                                               name  \
# 0   -12.628     0                           Keep A Song In Your Soul
# 1    -7.261     0                               I Put A Spell On You
# 2   -12.098     1                                       Golfing Papa
# 3    -7.311     1  True House Music - Xavier Santos & Carlos Gomi...
# 4    -6.036     0                                          Xuniverxe
#
#    popularity release_date  speechiness    tempo  valence  year
# 0          12         1920       0.0936  149.976   0.6340  1920
# 1           7     1/5/1920       0.0534   86.889   0.9500  1920
# 2           4         1920       0.1740   97.600   0.6890  1920
# 3          17     1/1/1920       0.0425  127.997   0.0422  1920
# 4           2    10/1/1920       0.0768  122.076   0.2990  1920

# %%
#Darel helping us replace extra characters
century_df['artists'] = century_df['artists'].str.replace("[","")
century_df['artists'][0]
# Out:
# "'Mamie Smith']"

# %%
century_df.columns
# Out:
# Index(['acousticness', 'artists', 'danceability', 'duration_ms', 'energy',
#        'explicit', 'id', 'instrumentalness', 'key', 'liveness', 'loudness',
#        'mode', 'name', 'popularity', 'release_date', 'speechiness', 'tempo',
#        'valence', 'year'],
#       dtype='object')

# %%
# choosing columns we want
century_transformed = century_df[['name',  'artists', 'year','popularity', 'acousticness', 'danceability', 
                                  'duration_ms', 'energy', 'instrumentalness', 'liveness', 'loudness', 
                                  'speechiness', 'tempo', 'valence','id']].copy()

# century_transformed.head()

#renaming columns
century_transformed = century_transformed.rename(columns={"name": "Song", "artists": "Artists_cen",\
                            "year":"Year", "popularity":"Popularity", "acousticness": "Acousticness",\
                            "danceability":"Danceability","duration_ms":"Duration (millisec)","energy":"Energy",\
                            "instrumentalness":"Instrumentalness","liveness":"Liveness","loudness":"Loudness",\
                            "speechiness":"Speechiness","tempo":"Tempo","valence":"Valence","id":"ID"})
# century_transformed.head()

# cleaning data by dropping duplicates/nulls and setting the index
century_transformed.drop_duplicates("ID", inplace=True)
century_transformed.set_index("Song", inplace=True)
century_transformed['Artists_cen'] = century_transformed['Artists_cen'].str.replace("[","")
century_transformed['Artists_cen'] = century_transformed['Artists_cen'].str.replace("'","")
century_transformed['Artists_cen'] = century_transformed['Artists_cen'].str.replace('"',"")
century_transformed['Artists_cen'] = century_transformed['Artists_cen'].str.replace("]","")
century_transformed.head()

# creating new instance of df and replacing nan values with empty strings
century_trans = century_transformed.replace(np.nan, '', regex=True)

century_trans.head()
# Out:
#                                                              Artists_cen  \
# Song
# Keep A Song In Your Soul                                     Mamie Smith
# I Put A Spell On You                                Screamin Jay Hawkins
# Golfing Papa                                                 Mamie Smith
# True House Music - Xavier Santos & Carlos Gomix...       Oscar Velazquez
# Xuniverxe                                                           Mixe
#
#                                                     Year  Popularity  \
# Song
# Keep A Song In Your Soul                            1920          12
# I Put A Spell On You                                1920           7
# Golfing Papa                                        1920           4
# True House Music - Xavier Santos & Carlos Gomix...  1920          17
# Xuniverxe                                           1920           2
#
#                                                     Acousticness  \
# Song
# Keep A Song In Your Soul                                0.991000
# I Put A Spell On You                                    0.643000
# Golfing Papa                                            0.993000
# True House Music - Xavier Santos & Carlos Gomix...      0.000173
# Xuniverxe                                               0.295000
#
#                                                     Danceability  \
# Song
# Keep A Song In Your Soul                                   0.598
# I Put A Spell On You                                       0.852
# Golfing Papa                                               0.647
# True House Music - Xavier Santos & Carlos Gomix...         0.730
# Xuniverxe                                                  0.704
#
#                                                     Duration (millisec)  \
# Song
# Keep A Song In Your Soul                                         168333
# I Put A Spell On You                                             150200
# Golfing Papa                                                     163827
# True House Music - Xavier Santos & Carlos Gomix...               422087
# Xuniverxe                                                        165224
#
#                                                     Energy  Instrumentalness  \
# Song
# Keep A Song In Your Soul                             0.224          0.000522
# I Put A Spell On You                                 0.517          0.026400
# Golfing Papa                                         0.186          0.000018
# True House Music - Xavier Santos & Carlos Gomix...   0.798          0.801000
# Xuniverxe                                            0.707          0.000246
#
#                                                     Liveness  Loudness  \
# Song
# Keep A Song In Your Soul                              0.3790   -12.628
# I Put A Spell On You                                  0.0809    -7.261
# Golfing Papa                                          0.5190   -12.098
# True House Music - Xavier Santos & Carlos Gomix...    0.1280    -7.311
# Xuniverxe                                             0.4020    -6.036
#
#                                                     Speechiness    Tempo  \
# Song
# Keep A Song In Your Soul                                 0.0936  149.976
# I Put A Spell On You                                     0.0534   86.889
# Golfing Papa                                             0.1740   97.600
# True House Music - Xavier Santos & Carlos Gomix...       0.0425  127.997
# Xuniverxe                                                0.0768  122.076
#
#                                                     Valence  \
# Song
# Keep A Song In Your Soul                             0.6340
# I Put A Spell On You                                 0.9500
# Golfing Papa                                         0.6890
# True House Music - Xavier Santos & Carlos Gomix...   0.0422
# Xuniverxe                                            0.2990
#
#                                                                         ID
# Song
# Keep A Song In Your Soul                            0cS0A1fUEUd1EW3FcF8AEI
# I Put A Spell On You                                0hbkKFIJm7Z05H8Zl9w30f
# Golfing Papa                                        11m7laMUgmOKqI3oYzuhne
# True House Music - Xavier Santos & Carlos Gomix...  19Lc5SfJJ5O1oaxY0fpwfh
# Xuniverxe                                           2hJjbsLCytGsnAHfdsLejp

# %%
# dropping artist_cen column, realized we don't need column anymore

century_new = century_trans.drop(labels="Artists_cen", axis=1)
century_new
# Out:
#                                                     Year  Popularity  \
# Song
# Keep A Song In Your Soul                            1920          12
# I Put A Spell On You                                1920           7
# Golfing Papa                                        1920           4
# True House Music - Xavier Santos & Carlos Gomix...  1920          17
# Xuniverxe                                           1920           2
# ...                                                  ...         ...
# A Little More                                       2021           0
# A Little More                                       2021           0
# A Little More                                       2021           0
# A Little More                                       2021           0
# champagne problems                                  2021          69
#
#                                                     Acousticness  \
# Song
# Keep A Song In Your Soul                                0.991000
# I Put A Spell On You                                    0.643000
# Golfing Papa                                            0.993000
# True House Music - Xavier Santos & Carlos Gomix...      0.000173
# Xuniverxe                                               0.295000
# ...                                                          ...
# A Little More                                           0.795000
# A Little More                                           0.795000
# A Little More                                           0.795000
# A Little More                                           0.795000
# champagne problems                                      0.920000
#
#                                                     Danceability  \
# Song
# Keep A Song In Your Soul                                   0.598
# I Put A Spell On You                                       0.852
# Golfing Papa                                               0.647
# True House Music - Xavier Santos & Carlos Gomix...         0.730
# Xuniverxe                                                  0.704
# ...                                                          ...
# A Little More                                              0.429
# A Little More                                              0.429
# A Little More                                              0.429
# A Little More                                              0.429
# champagne problems                                         0.462
#
#                                                     Duration (millisec)  \
# Song
# Keep A Song In Your Soul                                         168333
# I Put A Spell On You                                             150200
# Golfing Papa                                                     163827
# True House Music - Xavier Santos & Carlos Gomix...               422087
# Xuniverxe                                                        165224
# ...                                                                 ...
# A Little More                                                    144720
# A Little More                                                    144720
# A Little More                                                    144720
# A Little More                                                    144720
# champagne problems                                               244000
#
#                                                     Energy  Instrumentalness  \
# Song
# Keep A Song In Your Soul                             0.224          0.000522
# I Put A Spell On You                                 0.517          0.026400
# Golfing Papa                                         0.186          0.000018
# True House Music - Xavier Santos & Carlos Gomix...   0.798          0.801000
# Xuniverxe                                            0.707          0.000246
# ...                                                    ...               ...
# A Little More                                        0.211          0.000000
# A Little More                                        0.211          0.000000
# A Little More                                        0.211          0.000000
# A Little More                                        0.211          0.000000
# champagne problems                                   0.240          0.000000
#
#                                                     Liveness  Loudness  \
# Song
# Keep A Song In Your Soul                              0.3790   -12.628
# I Put A Spell On You                                  0.0809    -7.261
# Golfing Papa                                          0.5190   -12.098
# True House Music - Xavier Santos & Carlos Gomix...    0.1280    -7.311
# Xuniverxe                                             0.4020    -6.036
# ...                                                      ...       ...
# A Little More                                         0.1960   -11.665
# A Little More                                         0.1960   -11.665
# A Little More                                         0.1960   -11.665
# A Little More                                         0.1960   -11.665
# champagne problems                                    0.1130   -12.077
#
#                                                     Speechiness    Tempo  \
# Song
# Keep A Song In Your Soul                                 0.0936  149.976
# I Put A Spell On You                                     0.0534   86.889
# Golfing Papa                                             0.1740   97.600
# True House Music - Xavier Santos & Carlos Gomix...       0.0425  127.997
# Xuniverxe                                                0.0768  122.076
# ...                                                         ...      ...
# A Little More                                            0.0360   94.710
# A Little More                                            0.0360   94.710
# A Little More                                            0.0360   94.710
# A Little More                                            0.0360   94.710
# champagne problems                                       0.0377  171.319
#
#                                                     Valence  \
# Song
# Keep A Song In Your Soul                             0.6340
# I Put A Spell On You                                 0.9500
# Golfing Papa                                         0.6890
# True House Music - Xavier Santos & Carlos Gomix...   0.0422
# Xuniverxe                                            0.2990
# ...                                                     ...
# A Little More                                        0.2280
# A Little More                                        0.2280
# A Little More                                        0.2280
# A Little More                                        0.2280
# champagne problems                                   0.3200
#
#                                                                         ID
# Song
# Keep A Song In Your Soul                            0cS0A1fUEUd1EW3FcF8AEI
# I Put A Spell On You                                0hbkKFIJm7Z05H8Zl9w30f
# Golfing Papa                                        11m7laMUgmOKqI3oYzuhne
# True House Music - Xavier Santos & Carlos Gomix...  19Lc5SfJJ5O1oaxY0fpwfh
# Xuniverxe                                           2hJjbsLCytGsnAHfdsLejp
# ...                                                                    ...
# A Little More                                       45XnLMuqf3vRfskEAMUeCH
# A Little More                                       4pPFI9jsguIh3wC7Otoyy8
# A Little More                                       52YtxLVUyvtiGPxwwxayHZ
# A Little More                                       7tue2Wemjd0FZzRtDrQFZd
# champagne problems                                  1gcyHQpBQ1lfXGdhZmWrHP
#
# [172230 rows x 13 columns]

# %% [markdown]
# # Merging dataframes

# %%
spotify_merge = pd.merge(top50_trans, century_new, on="Song",how="left")
spotify_merge.drop_duplicates('index',inplace=True)
spotify_merge
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-57-f29f282a25bf> in <module>
#       1 spotify_merge = pd.merge(top50_trans, century_new, on="Song",how="left")
# ----> 2 spotify_merge.drop_duplicates('index',inplace=True)
#       3 spotify_merge
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in drop_duplicates(self, subset, keep, inplace, ignore_index)
#    5110
#    5111         inplace = validate_bool_kwarg(inplace, "inplace")
# -> 5112         duplicated = self.duplicated(subset, keep=keep)
#    5113
#    5114         result = self[-duplicated]
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in duplicated(self, subset, keep)
#    5246         diff = Index(subset).difference(self.columns)
#    5247         if not diff.empty:
# -> 5248             raise KeyError(diff)
#    5249
#    5250         vals = (col.values for name, col in self.items() if name in subset)
#
# KeyError: Index(['index'], dtype='object')
